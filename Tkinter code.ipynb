# %%
# Create Tkinter GUI
app = tk.Tk()
app.title("LLM Chatbot")
app.geometry("700x500")

# Input Label and Box
tk.Label(app, text="Enter your question:", font=("Arial", 12)).pack(pady=5)
input_box = tk.Text(app, height=5, width=70, font=("Arial", 12))
input_box.pack(pady=5)

# Submit Button
submit_button = tk.Button(app, text="Get Answer", font=("Arial", 12), command=handle_query)
submit_button.pack(pady=10)

# Output Label and Scrolled Text Box
tk.Label(app, text="Response:", font=("Arial", 12)).pack(pady=5)
output_box = scrolledtext.ScrolledText(app, height=15, width=70, font=("Arial", 12))
output_box.pack(pady=5)

# Run the Application
app.mainloop()
